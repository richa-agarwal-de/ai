# %% [markdown]
# <a href="https://colab.research.google.com/github/richa-agarwal-de/ai/blob/main/AI_Langgraph_AgenticAI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import openai
import re
import httpx
import os
from dotenv import load_dotenv

_ = load_dotenv() # Load environment variables from .env file
from openai import OpenAI

# %%
client = OpenAI() # Pass the API key
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipython-input-9-373903288.py in <cell line: 0>()
# ----> 1 client = OpenAI() # Pass the API key
#
# /usr/local/lib/python3.11/dist-packages/openai/_client.py in __init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128             api_key = os.environ.get("OPENAI_API_KEY")
#     129         if api_key is None:
# --> 130             raise OpenAIError(
#     131                 "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     132             )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
